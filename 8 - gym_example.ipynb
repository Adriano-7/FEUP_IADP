# %% [markdown]
# #### Import Pandas module as pd

# %%
import pandas as pd

# %% [markdown]
# #### Reads the .csv file 'gym.csv' using ';' as separator

# %%
df = pd.read_csv('gym.csv', sep = ',', parse_dates=['date'])
# Out:
# C:\Users\adria_ek1ciji\AppData\Local\Temp\ipykernel_6480\80825765.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df = pd.read_csv('gym.csv', sep = ',', parse_dates=['date'])

# %% [markdown]
# #### Shows the first n rows from the DataFrame (5 rows if the argument is ommited)

# %%
df.head(3)
# Out:
#         id            name       date  height  weight  age  hours   status  \
# 0  1373913  Marisa Martins 2013-02-05     155      48   45      3  married
# 1  1109818    Rita Fonseca 2018-08-28     166      54   45      3  married
# 2  1158813   Joana Freitas 2013-10-21     150      42   52      3    widow
#
#    children sex
# 0         2   F
# 1         3   F
# 2         1   F

# %% [markdown]
# #### Shows the last n rows from the DataFrame (5 rows if the argument is ommited)

# %%
df.tail(3)
# Out:
#          id               name       date  height  weight  age  hours  \
# 57  1150114  Antonio Goncalves 2014-11-22     158      49   34      3
# 58  1658815     Manuel Freitas 2015-11-06     170      51   57      1
# 59  1769504       Joao Tavares 2004-06-08     177      85   32      3
#
#      status  children sex
# 57   single         0   M
# 58    widow         2   M
# 59  married         2   M

# %% [markdown]
# #### Get the number of lines and columns of the DataFrame

# %%
df.shape
# Out:
# (60, 10)

# %% [markdown]
# #### General info about the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        60 non-null     int64
#  1   name      60 non-null     object
#  2   date      60 non-null     datetime64[ns]
#  3   height    60 non-null     int64
#  4   weight    60 non-null     int64
#  5   age       60 non-null     int64
#  6   hours     60 non-null     int64
#  7   status    60 non-null     object
#  8   children  60 non-null     int64
#  9   sex       60 non-null     object
# dtypes: datetime64[ns](1), int64(6), object(3)
# memory usage: 4.8+ KB

# %% [markdown]
# #### Get the type of data in each DataFrame column. Type object is Python string

# %%
df.dtypes
# Out:
# id                   int64
# name                object
# date        datetime64[ns]
# height               int64
# weight               int64
# age                  int64
# hours                int64
# status              object
# children             int64
# sex                 object
# dtype: object

# %% [markdown]
# #### Access the row with label 0. Returns a series

# %%
df.loc[0]
# Out:
# id                      1373913
# name             Marisa Martins
# date        2013-02-05 00:00:00
# height                      155
# weight                       48
# age                          45
# hours                         3
# status                  married
# children                      2
# sex                           F
# Name: 0, dtype: object

# %%
type(df.loc[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Access all the rows from column 'age'

# %%
s = df.loc[:,'age']

# %%
s.head()
# Out:
# 0    45
# 1    45
# 2    52
# 3    59
# 4    43
# Name: age, dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Access value in row with label 0 in column 'age'

# %%
df.loc[0,'age']
# Out:
# 45

# %% [markdown]
# #### Access the rows with labels 0, 2 and 4

# %%
df.loc[[0,2,4]]
# Out:
#         id               name       date  height  weight  age  hours   status  \
# 0  1373913     Marisa Martins 2013-02-05     155      48   45      3  married
# 2  1158813      Joana Freitas 2013-10-21     150      42   52      3    widow
# 4  1974509  Francisco Fonseca 2009-08-22     162      52   43      2  married
#
#    children sex
# 0         2   F
# 2         1   F
# 4         1   M

# %% [markdown]
# #### Access values in rows with labels 0 and 2 and columns 'name' and 'age'

# %%
df.loc[[0,2],['name', 'age']]
# Out:
#              name  age
# 0  Marisa Martins   45
# 2   Joana Freitas   52

# %% [markdown]
# #### Access the values between rows with labels 0 and 2 and between columns 'name' and 'age'

# %%
df.loc[0:2,'name':'age']
# Out:
#              name       date  height  weight  age
# 0  Marisa Martins 2013-02-05     155      48   45
# 1    Rita Fonseca 2018-08-28     166      54   45
# 2   Joana Freitas 2013-10-21     150      42   52

# %% [markdown]
# #### Access the value in row 1 and column 1

# %%
df.iloc[1,1]
# Out:
# 'Rita Fonseca'

# %% [markdown]
# #### Access to all the values in row 1

# %%
df.iloc[1,:]
# Out:
# id                      1109818
# name               Rita Fonseca
# date        2018-08-28 00:00:00
# height                      166
# weight                       54
# age                          45
# hours                         3
# status                  married
# children                      3
# sex                           F
# Name: 1, dtype: object

# %% [markdown]
# #### Access rows between 0 and 2 and columns between 2 and 4

# %%
df.iloc[0:2,2:4]
# Out:
#         date  height
# 0 2013-02-05     155
# 1 2018-08-28     166

# %% [markdown]
# #### Row index, by default an integer row number

# %%
df.index
# Out:
# RangeIndex(start=0, stop=60, step=1)

# %% [markdown]
# #### Column index - column names

# %%
df.columns
# Out:
# Index(['id', 'name', 'date', 'height', 'weight', 'age', 'hours', 'status',
#        'children', 'sex'],
#       dtype='object')

# %% [markdown]
# #### Set column 'name' as the new index

# %%
df.set_index('name', inplace=True)

# %% [markdown]
# #### The values in a row can be accessed using the index of the row

# %%
df.loc['Jose Carvalho']
# Out:
# id                      1871004
# date        2004-09-17 00:00:00
# height                      153
# weight                       67
# age                          26
# hours                         7
# status                  married
# children                      1
# sex                           M
# Name: Jose Carvalho, dtype: object

# %% [markdown]
# #### The DataFrame index can be sorted

# %%
df.sort_index(ascending=True)
# Out:
#                   name       id       date  years  height  weight  age  hours  \
# 0       Marisa Martins  1373913 2013-02-05      8     155      48   45      3
# 1         Rita Fonseca  1109818 2018-08-28      3     166      54   45      3
# 2        Joana Freitas  1158813 2013-10-21      8     150      42   52      3
# 3      Joana Goncalves  1566515 2015-11-16      6     161      49   59      2
# 4    Francisco Fonseca  1974509 2009-08-22     12     162      52   43      2
# 5       Manuel Martins  1767703 2003-01-25     18     179      85   24      6
# 6     Florbela Freitas  1071208 2008-09-26     13     166      53   28      5
# 7            Rita Cruz  1930916 2016-10-11      5     168      52   56      3
# 8      Antonio Pereira  1811504 2004-02-16     17     154      61   51      2
# 9      Manuel Carvalho  1235914 2014-08-27      7     158      45   38      3
# 10      Manuel Marinho  1417018 2018-06-20      3     173      57   40      3
# 11        Joao Freitas  1642316 2016-10-23      5     165      50   54      3
# 12    Susana Goncalves  1170413 2013-07-03      8     157      65   40      2
# 13   Francisco Freitas  1560118 2018-07-15      3     152      53   41      3
# 14   Francisco Martins  1410714 2014-11-25      7     153      58   24      7
# 15      Susana Madeira  1436908 2008-09-05     13     160      49   56      2
# 16     Francisco Pinho  1294215 2015-08-25      6     154      58   23      6
# 17        Joao Madeira  1286112 2012-08-19      9     152      78   29      6
# 18        Manuel Pinho  1315817 2017-12-23      4     179      58   29      5
# 19  Catarina Goncalves  1055806 2006-09-21     15     168      53   59      2
# 20    Florbela Marinho  1305314 2014-04-24      7     154      62   36      4
# 21   Francisco Pereira  1953503 2003-03-04     18     170      79   49      2
# 22        Rita Madeira  1204821 2021-11-06      0     151      45   44      2
# 23  Florbela Goncalves  1998809 2009-07-01     12     169      50   39      4
# 24    Catarina Freitas  1105321 2021-10-07      0     166      70   40      4
# 25     Antonio Fonseca  1867513 2013-07-06      8     164      53   41      3
# 26       Catarina Cruz  1967921 2021-10-13      0     176      61   30      5
# 27           Jose Cruz  1068508 2008-12-02     13     177      90   27      6
# 28          Joao Pinho  1152520 2020-11-29      1     154      66   55      1
# 29      Manuel Fonseca  1373707 2007-09-24     14     175     102   40      3
# 30     Pedro Goncalves  1776804 2004-09-03     17     156      46   32      5
# 31       Joana Pereira  1147413 2013-03-24      8     162      49   34      5
# 32       Joana Marinho  1466415 2015-11-26      6     164      51   57      1
# 33       Pedro Madeira  1610119 2019-05-19      2     163      53   28      5
# 34         Manuel Cruz  1710710 2010-11-27     11     178      55   44      3
# 35       Sonia Marinho  1564109 2009-06-11     12     156      46   41      2
# 36         Marisa Cruz  1223600 2000-10-16     21     171      61   42      4
# 37    Florbela Pereira  1705816 2016-12-08      5     171      58   32      6
# 38   Francisco Madeira  1692512 2012-09-24      9     154      49   23      8
# 39    Catarina Pereira  1177213 2013-10-13      8     175      88   54      1
# 40         Sonia Pinho  1337319 2019-11-02      2     177      63   34      5
# 41       Jose Carvalho  1871004 2004-09-17     17     153      67   26      7
# 42      Manuel Madeira  1098118 2018-06-30      3     165      55   34      4
# 43   Catarina Carvalho  1058304 2004-09-25     17     150      45   59      2
# 44  Francisco Carvalho  1653302 2002-05-09     19     150      66   23      7
# 45       Sonia Fonseca  1320306 2006-12-09     15     152      46   37      4
# 46    Catarina Madeira  1200611 2011-10-24     10     154      63   46      2
# 47      Joana Carvalho  1758412 2012-09-08      9     174      59   37      3
# 48     Sonia Goncalves  1471416 2016-07-05      5     170      52   43      3
# 49       Sonia Pereira  1374905 2005-10-17     16     178      94   37      3
# 50          Pedro Cruz  1221721 2021-11-08      0     161      50   43      3
# 51        Jose Fonseca  1359417 2017-10-28      4     155      68   41      3
# 52    Catarina Marinho  1331601 2001-01-15     20     178      63   43      3
# 53       Pedro Fonseca  1065208 2008-09-02     13     153      80   49      1
# 54       Florbela Cruz  1971506 2006-08-10     15     166      54   47      3
# 55      Susana Marinho  1521112 2012-08-18      9     174      60   35      5
# 56    Antonio Carvalho  1856501 2001-02-07     20     159      73   24      6
# 57   Antonio Goncalves  1150114 2014-11-22      7     158      49   34      3
# 58      Manuel Freitas  1658815 2015-11-06      6     170      51   57      1
# 59        Joao Tavares  1769504 2004-06-08     17     177      85   32      3
#
#       status  children sex  days  old_client
# 0    married         2   F  2920        True
# 1    married         3   F  1095       False
# 2      widow         1   F  2920        True
# 3    married         2   F  2190       False
# 4    married         1   M  4380        True
# 5     single         0   M  6570        True
# 6     single         0   F  4745        True
# 7    married         2   F  1825       False
# 8    married         1   M  6205        True
# 9    married         2   M  2555       False
# 10  divorced         2   M  1095       False
# 11   married         2   M  1825       False
# 12   married         5   F  2920        True
# 13   married         2   M  1095       False
# 14    single         0   M  2555       False
# 15  divorced         2   F  4745        True
# 16    single         3   M  2190       False
# 17    single         1   M  3285        True
# 18    single         0   M  1460       False
# 19     widow         3   F  5475        True
# 20   married         1   F  2555       False
# 21   married         1   M  6570        True
# 22   married         2   F     0       False
# 23    single         1   F  4380        True
# 24    single         0   F     0       False
# 25   married         3   M  2920        True
# 26    single         1   F     0       False
# 27   married         0   M  4745        True
# 28    single         0   M   365       False
# 29   married         1   M  5110        True
# 30    single         0   M  6205        True
# 31   married         2   F  2920        True
# 32   married         3   F  2190       False
# 33   married         4   M   730       False
# 34   married         2   M  4015        True
# 35   married         3   F  4380        True
# 36   married         2   F  7665        True
# 37   married         0   F  1825       False
# 38    single         0   M  3285        True
# 39   married         1   F  2920        True
# 40    single         0   F   730       False
# 41   married         1   M  6205        True
# 42   married         1   M  1095       False
# 43   married         4   F  6205        True
# 44    single         0   M  6935        True
# 45   married         1   F  5475        True
# 46    single         2   F  3650        True
# 47   married         2   F  3285        True
# 48   married         2   F  1825       False
# 49   married         3   F  5840        True
# 50    single         1   M     0       False
# 51   married         0   M  1460       False
# 52   married         2   F  7300        True
# 53   married         2   M  4745        True
# 54   married         3   F  5475        True
# 55    single         0   F  3285        True
# 56    single         0   M  7300        True
# 57    single         0   M  2555       False
# 58     widow         2   M  2190       False
# 59   married         2   M  6205        True

# %% [markdown]
# #### The DataFrame can be sorted by the values in another column

# %%
df.sort_values('age').head(5)
# Out:
#                          id       date  height  weight  age  hours  status  \
# name
# Francisco Pinho     1294215 2015-08-25     154      58   23      6  single
# Francisco Carvalho  1653302 2002-05-09     150      66   23      7  single
# Francisco Madeira   1692512 2012-09-24     154      49   23      8  single
# Antonio Carvalho    1856501 2001-02-07     159      73   24      6  single
# Manuel Martins      1767703 2003-01-25     179      85   24      6  single
#
#                     children sex
# name
# Francisco Pinho            3   M
# Francisco Carvalho         0   M
# Francisco Madeira          0   M
# Antonio Carvalho           0   M
# Manuel Martins             0   M

# %% [markdown]
# #### Reset the index to the default

# %%
df.reset_index(inplace=True)

# %% [markdown]
# #### Statistical functions can be used in DataFrame column series

# %%
df['age'].mean()
# Out:
# 40.083333333333336

# %%
df['height'].max()
# Out:
# 179

# %%
df['weight'].min()
# Out:
# 42

# %%
df.describe()
# Out:
#                  id      height     weight        age      hours   children
# count  6.000000e+01   60.000000   60.00000  60.000000  60.000000  60.000000
# mean   1.461868e+06  163.533333   59.95000  40.083333   3.600000   1.483333
# std    2.932733e+05    9.307308   13.55144  10.469150   1.719282   1.214205
# min    1.055806e+06  150.000000   42.00000  23.000000   1.000000   0.000000
# 25%    1.203768e+06  154.000000   50.00000  32.000000   2.000000   0.000000
# 50%    1.392810e+06  163.500000   56.00000  40.000000   3.000000   1.500000
# 75%    1.707040e+06  171.000000   65.25000  46.250000   5.000000   2.000000
# max    1.998809e+06  179.000000  102.00000  59.000000   8.000000   5.000000

# %% [markdown]
# #### The DataFrame elements can be accessed in Python code

# %%
def avg(col_name):
    s = 0
    n = len(df[col_name])
    for i in df[col_name]:
        s = s + i
    avg = s / n
    return avg

# %%
avg('age')
# Out:
# 40.083333333333336

# %% [markdown]
# **Create a new column with the number of years at the gym and insert it at position 3**

# %%
df.insert(3, 'years', 2021 - df['date'].dt.year)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.insert(3, 'years', 2021 - df['date'].dt.year)
#
# NameError: name 'df' is not defined

# %% [markdown]
# **Create new columns at last position**

# %%
df['days'] = df['years'] * 365

# %%
df['old_client'] = df['years'] > 7

# %%
df.head(3)
# Out:
#              name       id       date  years  height  weight  age  hours  \
# 0  Marisa Martins  1373913 2013-02-05      8     155      48   45      3
# 1    Rita Fonseca  1109818 2018-08-28      3     166      54   45      3
# 2   Joana Freitas  1158813 2013-10-21      8     150      42   52      3
#
#     status  children sex  days  old_client
# 0  married         2   F  2920        True
# 1  married         3   F  1095       False
# 2    widow         1   F  2920        True

# %% [markdown]
# **Remove the columns years, days and old_client**

# %%
df.drop('years', axis = 1, inplace = True)

# %%
del df['days']

# %%
old_client = df.pop('old_client')

# %%
df.head(3)
# Out:
#              name       id       date  height  weight  age  hours   status  \
# 0  Marisa Martins  1373913 2013-02-05     155      48   45      3  married
# 1    Rita Fonseca  1109818 2018-08-28     166      54   45      3  married
# 2   Joana Freitas  1158813 2013-10-21     150      42   52      3    widow
#
#    children sex
# 0         2   F
# 1         3   F
# 2         1   F

# %% [markdown]
# **Set the column names**

# %%
df.columns = ['Name', 'Id', 'Date', 'Height', 'Weight', 'Age', 'Hours', 'Status', 'Children', 'Sex']

# %%
df.head(3)
# Out:
#              Name       Id       Date  Height  Weight  Age  Hours   Status  \
# 0  Marisa Martins  1373913 2013-02-05     155      48   45      3  married
# 1    Rita Fonseca  1109818 2018-08-28     166      54   45      3  married
# 2   Joana Freitas  1158813 2013-10-21     150      42   52      3    widow
#
#    Children Sex
# 0         2   F
# 1         3   F
# 2         1   F

# %% [markdown]
# **Change the column name using the str replace method**

# %%
df.columns = df.columns.str.replace('Age', 'age')

# %%
df.head(3)
# Out:
#              Name       Id       Date  Height  Weight  age  Hours   Status  \
# 0  Marisa Martins  1373913 2013-02-05     155      48   45      3  married
# 1    Rita Fonseca  1109818 2018-08-28     166      54   45      3  married
# 2   Joana Freitas  1158813 2013-10-21     150      42   52      3    widow
#
#    Children Sex
# 0         2   F
# 1         3   F
# 2         1   F

# %% [markdown]
# **Change the column names using the rename method**

# %%
df.rename(columns={'Name':'name', 'Id': 'id'}, inplace=True)

# %%
df.head(3)
# Out:
#              name       id       Date  Height  Weight  age  Hours   Status  \
# 0  Marisa Martins  1373913 2013-02-05     155      48   45      3  married
# 1    Rita Fonseca  1109818 2018-08-28     166      54   45      3  married
# 2   Joana Freitas  1158813 2013-10-21     150      42   52      3    widow
#
#    Children Sex
# 0         2   F
# 1         3   F
# 2         1   F

# %% [markdown]
# **Change the column names using list comprehension**

# %%
df.columns = [x.lower() for x in df.columns]

# %%
df.head(3)
# Out:
#              name       id       date  height  weight  age  hours   status  \
# 0  Marisa Martins  1373913 2013-02-05     155      48   45      3  married
# 1    Rita Fonseca  1109818 2018-08-28     166      54   45      3  married
# 2   Joana Freitas  1158813 2013-10-21     150      42   52      3    widow
#
#    children sex
# 0         2   F
# 1         3   F
# 2         1   F

# %% [markdown]
# #### Assign a new set of values to a row

# %%
df.loc[0] = ['Antonio Gomes',1354891, '2018-05-20',100, 20, 30, 2, 'widow',1, 'M']
df.head(2)
# Out:
#             name       id       date  height  weight  age  hours   status  \
# 0  Antonio Gomes  1354891 2018-05-20     100      20   30      2    widow
# 1   Rita Fonseca  1109818 2018-08-28     166      54   45      3  married
#
#    children sex
# 0         1   M
# 1         3   F

# %% [markdown]
# **Change some of the values in a row**

# %%
df.loc[0,['id', 'status']] = [1234567, 'single']
df.head(2)
# Out:
#             name       id       date  height  weight  age  hours   status  \
# 0  Antonio Gomes  1234567 2018-05-20     100      20   30      2   single
# 1   Rita Fonseca  1109818 2018-08-28     166      54   45      3  married
#
#    children sex
# 0         1   M
# 1         3   F

# %% [markdown]
# **Append a row to a DataFrame**

# %%
df = df.append({'name':'Xavier Furtado','id':1111111,'height':150},ignore_index=True)
df.tail(2)
# Out:
# C:\Users\adria_ek1ciji\AppData\Local\Temp\ipykernel_6480\1640448981.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'name':'Xavier Furtado','id':1111111,'height':150},ignore_index=True)
#               name       id       date  height  weight   age  hours   status  \
# 59    Joao Tavares  1769504 2004-06-08     177    85.0  32.0    3.0  married
# 60  Xavier Furtado  1111111        NaT     150     NaN   NaN    NaN      NaN
#
#     children  sex
# 59       2.0    M
# 60       NaN  NaN

# %% [markdown]
# **Delete a row**

# %%
df.drop(60, inplace=True)
df.tail(2)
# Out:
#               name       id       date  height  weight   age  hours   status  \
# 58  Manuel Freitas  1658815 2015-11-06     170    51.0  57.0    1.0    widow
# 59    Joao Tavares  1769504 2004-06-08     177    85.0  32.0    3.0  married
#
#     children sex
# 58       2.0   M
# 59       2.0   M

# %% [markdown]
# **Select the customers over 55 years old**

# %%
df.loc[df['age'] > 55]
# Out:
#                   name       id       date  height  weight   age  hours  \
# 3      Joana Goncalves  1566515 2015-11-16     161    49.0  59.0    2.0
# 7            Rita Cruz  1930916 2016-10-11     168    52.0  56.0    3.0
# 15      Susana Madeira  1436908 2008-09-05     160    49.0  56.0    2.0
# 19  Catarina Goncalves  1055806 2006-09-21     168    53.0  59.0    2.0
# 32       Joana Marinho  1466415 2015-11-26     164    51.0  57.0    1.0
# 43   Catarina Carvalho  1058304 2004-09-25     150    45.0  59.0    2.0
# 58      Manuel Freitas  1658815 2015-11-06     170    51.0  57.0    1.0
#
#       status  children sex
# 3    married       2.0   F
# 7    married       2.0   F
# 15  divorced       2.0   F
# 19     widow       3.0   F
# 32   married       3.0   F
# 43   married       4.0   F
# 58     widow       2.0   M

# %% [markdown]
# **Select the customers over 55 years old and weight over 50kg**

# %%
df.loc[(df['age'] > 55) & (df['weight'] > 50)]
# Out:
#                   name       id       date  height  weight   age  hours  \
# 7            Rita Cruz  1930916 2016-10-11     168    52.0  56.0    3.0
# 19  Catarina Goncalves  1055806 2006-09-21     168    53.0  59.0    2.0
# 32       Joana Marinho  1466415 2015-11-26     164    51.0  57.0    1.0
# 58      Manuel Freitas  1658815 2015-11-06     170    51.0  57.0    1.0
#
#      status  children sex
# 7   married       2.0   F
# 19    widow       3.0   F
# 32  married       3.0   F
# 58    widow       2.0   M

# %% [markdown]
# **Select the customers over 55 or under 24 years old. View name and age**

# %%
df.loc[(df['age'] > 57) | (df['age'] < 24), ['name', 'age']]
# Out:
#                   name   age
# 3      Joana Goncalves  59.0
# 16     Francisco Pinho  23.0
# 19  Catarina Goncalves  59.0
# 38   Francisco Madeira  23.0
# 43   Catarina Carvalho  59.0
# 44  Francisco Carvalho  23.0

# %% [markdown]
# **Select the customers with status: divorced or widow**

# %%
df.loc[df['status'].isin(['divorced','widow'])]
# Out:
#                   name       id       date  height  weight   age  hours  \
# 2        Joana Freitas  1158813 2013-10-21     150    42.0  52.0    3.0
# 10      Manuel Marinho  1417018 2018-06-20     173    57.0  40.0    3.0
# 15      Susana Madeira  1436908 2008-09-05     160    49.0  56.0    2.0
# 19  Catarina Goncalves  1055806 2006-09-21     168    53.0  59.0    2.0
# 58      Manuel Freitas  1658815 2015-11-06     170    51.0  57.0    1.0
#
#       status  children sex
# 2      widow       1.0   F
# 10  divorced       2.0   M
# 15  divorced       2.0   F
# 19     widow       3.0   F
# 58     widow       2.0   M

# %% [markdown]
# **Select the customers with name Freitas**

# %%
df.loc[df['name'].str.contains('Freitas',na=False)]
# Out:
#                  name       id       date  height  weight   age  hours  \
# 2       Joana Freitas  1158813 2013-10-21     150    42.0  52.0    3.0
# 6    Florbela Freitas  1071208 2008-09-26     166    53.0  28.0    5.0
# 11       Joao Freitas  1642316 2016-10-23     165    50.0  54.0    3.0
# 13  Francisco Freitas  1560118 2018-07-15     152    53.0  41.0    3.0
# 24   Catarina Freitas  1105321 2021-10-07     166    70.0  40.0    4.0
# 58     Manuel Freitas  1658815 2015-11-06     170    51.0  57.0    1.0
#
#      status  children sex
# 2     widow       1.0   F
# 6    single       0.0   F
# 11  married       2.0   M
# 13  married       2.0   M
# 24   single       0.0   F
# 58    widow       2.0   M

# %% [markdown]
# **Apply a function to all the elements of a Series**

# %%
df['status'] = df['status'].apply(str.upper)
df.head(2)
# Out:
#             name       id       date  height  weight   age  hours   status  \
# 0  Antonio Gomes  1234567 2018-05-20     100    20.0  30.0    2.0   SINGLE
# 1   Rita Fonseca  1109818 2018-08-28     166    54.0  45.0    3.0  MARRIED
#
#    children sex
# 0       1.0   M
# 1       3.0   F

# %% [markdown]
# **Get the unique elements from a series**

# %%
df['status'].unique()
# Out:
# array(['SINGLE', 'MARRIED', 'WIDOW', 'DIVORCED'], dtype=object)

# %% [markdown]
# **Return the number of counts of unique values**

# %%
df['status'].value_counts()
# Out:
# married     35
# single      20
# widow        3
# divorced     2
# Name: status, dtype: int64

# %%
df['status'] = df['status'].apply(str.lower)

# %% [markdown]
# **Groupby can be used to count values by group**

# %%
df.groupby('sex')['status'].value_counts()
# Out:
# sex  status
# F    married     19
#      single       7
#      widow        2
#      divorced     1
# M    married     16
#      single      13
#      divorced     1
#      widow        1
# Name: status, dtype: int64

# %% [markdown]
# **Write a DataFrame to a .csv and Excel files**

# %%
df.to_csv('gym_new.csv', sep = ',', index=False)

# %%
df.to_excel('gym_new.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df.to_excel('gym_new.xlsx', index=False)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:2374, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2361 from pandas.io.formats.excel import ExcelFormatter
#    2363 formatter = ExcelFormatter(
#    2364     df,
#    2365     na_rep=na_rep,
#    (...)
#    2372     inf_rep=inf_rep,
#    2373 )
# -> 2374 formatter.write(
#    2375     excel_writer,
#    2376     sheet_name=sheet_name,
#    2377     startrow=startrow,
#    2378     startcol=startcol,
#    2379     freeze_panes=freeze_panes,
#    2380     engine=engine,
#    2381     storage_options=storage_options,
#    2382 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\formats\excel.py:918, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     914     need_save = False
#     915 else:
#     916     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     917     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 918     writer = ExcelWriter(  # type: ignore[abstract]
#     919         writer, engine=engine, storage_options=storage_options
#     920     )
#     921     need_save = True
#     923 try:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\excel\_openpyxl.py:56, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      43 def __init__(
#      44     self,
#      45     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      54 ) -> None:
#      55     # Use the openpyxl module as the Excel writer.
# ---> 56     from openpyxl.workbook import Workbook
#      58     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      60     super().__init__(
#      61         path,
#      62         mode=mode,
#    (...)
#      65         engine_kwargs=engine_kwargs,
#      66     )
#
# ModuleNotFoundError: No module named 'openpyxl'
